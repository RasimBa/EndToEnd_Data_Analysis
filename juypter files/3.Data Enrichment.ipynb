# %% [markdown]
# # Data Enrichment for Bad Data

# %% [markdown]
# # Google Places API Integration and Data Enrichment Process
#
# ### 1. Setting Up Google Cloud Console
#
# I started by opening the **Google Cloud Console** and creating a new project to manage and track API usage. This project is necessary for accessing Google's APIs. After the project was created, I navigated to the **API & Services Library** and enabled the **Google Places API**, which provides information such as business addresses and other related details.
#
# ### 2. Creating the API Key
#
# Next, I created an **API key** to authenticate requests to the Google Places API. The API key is used by the code to send requests to the API and retrieve business information like addresses and phone numbers. This key must be kept private to avoid unauthorized use.
#
#
# ### 3. Writing the Code
#
# I developed two key functions to interact with the Google Places API:
#
# - **`get_place_id()`**: This function sends a query to the Google Places API using the company name, street address, and country to form a search query. The function returns the **Place ID** and **formatted address** of the business, which is essential for fetching more details.
#
# - **`get_place_details()`**: After retrieving the **Place ID** from the previous function, this function queries the **Place Details API** to retrieve additional information about the business, such as the **phone number**. The function returns the phone number if it’s available.
#
# These functions help retrieve both the address and phone number of the business, which can then be used to enrich the dataset.
#
# ### 4. Enriching the Dataset
#
# The main function, **`enrich_bad_data()`**, iterates over a DataFrame (`bad_data`) that contains company information. For each company, if certain fields (such as the **cleaned phone number** or **street address**) are missing, the function first uses `get_place_id()` to query the **Google Places API** for the **Place ID** and address.
#
# If a **Place ID** is found, the function then calls `get_place_details()` to retrieve the business's phone number. If either the address or phone number is found, it is added to new columns (`new_address` and `new_phone_number`) in the DataFrame.
#
# An additional column, **`enrichment`**, is used to track whether any new data was added to the row. If the business's information is successfully enriched (i.e., a new address or phone number is added), the row is marked as **"enriched"**.
#
# ### Code Explanation
#
# - **`get_place_id()`**:
#   - This function sends a request to the Google Places API to retrieve the **Place ID** and **formatted address** of a business based on the company name, street, and country.
#   - It returns the **Place ID** and address if found.
#
# - **`get_place_details()`**:
#   - This function uses the **Place ID** obtained from `get_place_id()` to query the **Place Details API** and retrieve the business's **phone number**.
#   - It returns the phone number if available.
#
# - **`enrich_bad_data()`**:
#   - This function loops through each row of the DataFrame and checks if essential fields (like phone numbers or addresses) are missing.
#   - If data is missing, it calls `get_place_id()` and `get_place_details()` to fetch the necessary information.
#   - The retrieved data is stored in two new columns: `new_address` and `new_phone_number`. The **enrichment status** is tracked with an additional column called `enrichment`, indicating whether the row has been updated.
#
# ### Summary
#
# This process allows for filling in missing business data (like **addresses** and **phone numbers**) using the **Google Places API**, enriching the dataset with up-to-date information. The enriched data is saved in new columns (`new_address`, `new_phone_number`), and the process is tracked using an **enrichment status column** to indicate which rows have been successfully updated.
#
# <span style = "color:red" > [Note] During the enrichment process for about 80% of the leads - new addresses and phone numbers are generated </span>

# %% [markdown]
# ### Importing statements

# %%
import pandas as pd
import requests # allows you to send HTTP requests (such as GET or POST) to web services or APIs and retrieve responses
# pip install requests - if needed

# %%
# file location
file_path = '../Inputs/leads_in_review_data.xlsx' # relative path
# read data
bad_data = pd.read_excel(file_path)

# %%
import pandas as pd
import requests

# I used here the API KEY of mine
API_KEY = 'insert_your_API_Key_here_for_the_code_to_run' #if necessary please ask for the key


# Function to fetch business details from Google Places API
def get_place_id(company_name, street=None, country=None):
    try:
        search_url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json"
        query = f"{company_name}"
        if street:
            query += f", {street}"
        if country:
            query += f", {country}"
        
        params = {
            'input': query,
            'inputtype': 'textquery',
            'fields': 'place_id,formatted_address',
            'key': API_KEY
        }
        response = requests.get(search_url, params=params)
        print(f"API Response for {company_name}: {response.json()}")  # Debugging: print API response
        results = response.json().get('candidates', [])
        if results:
            business_info = results[0]
            return {
                'place_id': business_info.get('place_id', None),
                'address': business_info.get('formatted_address', None)
            }
        return None
    except Exception as e:
        print(f"Error fetching place ID for {company_name}: {e}")
        return None

# Function to fetch additional details (like phone number) using Place Details API
def get_place_details(place_id):
    try:
        details_url = "https://maps.googleapis.com/maps/api/place/details/json"
        params = {
            'place_id': place_id,
            'fields': 'formatted_phone_number',
            'key': API_KEY
        }
        response = requests.get(details_url, params=params)
        print(f"Place Details Response: {response.json()}")  # Debugging: print API response
        result = response.json().get('result', {})
        return {
            'phone': result.get('formatted_phone_number', None)
        }
    except Exception as e:
        print(f"Error fetching place details: {e}")
        return None

# Function to enrich the bad_data DataFrame and add new columns
def enrich_bad_data(df):
    df['new_address'] = None  # Initialize new address column
    df['new_phone_number'] = None  # Initialize new phone number column
    df['enrichment'] = 'not enriched'  # Initialize the enrichment column
    
    for index, row in df.iterrows():
        enrichment_made = False  # Track whether any enrichment was made
        
        company_name = row['firma']
        street = row.get('street')
        country = row.get('country')

        # Fetch business info using the Google Places API
        business_info = get_place_id(company_name, street, country)

        if business_info:
            place_id = business_info.get('place_id')
            if place_id:
                # Fetch phone number and other details using the Place Details API
                place_details = get_place_details(place_id)

                # Add the new phone number if available
                if place_details.get('phone'):
                    df.at[index, 'new_phone_number'] = place_details.get('phone')
                    enrichment_made = True

            # Add the new address if available
            if business_info.get('address'):
                df.at[index, 'new_address'] = business_info.get('address')
                enrichment_made = True

        # Mark as "enriched" if any new data was added
        if enrichment_made:
            df.at[index, 'enrichment'] = 'enriched'

    return df

# Enrich the dataset by adding new information as columns (e.g., address, phone number)
enriched_bad_data = enrich_bad_data(bad_data)

# Display the enriched data with new columns
enriched_bad_data
# Out:
# API Response for Autohaus Hentschel GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Autohaus Siegmar GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Autohaus Zückner GmbH & Co. KG: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Auto Böhler: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for EJP Frank Bach & Katarzyna Bach GbR: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for BREMSKERL-REIBBELAGWERKE Emmerling GMBH & CO. KG: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Werner Bölling GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for ratioparts® Ersatzteile-Vertriebs GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Robert Neugebauer & Sohn: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Autohaus Peene GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for GTÜ Gesellschaft für Technische Überwachung mbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for MotoPro GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Lohmann CT Line Nutzfahrzeuge UG: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for MA - Reifendienst: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Taxi Krümmel, Inh. Hans Jürgen Krümmel: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Alf Taxi, Inhaber: Torsten Sitte: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Taxi H. ten Brink: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for BST-Sutter GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Caravan-Park-Elstorf, Inh. Sascha Schacht: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Autolackiererei Loui Greco: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Wilhelm-Bau Bauunternehmen GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for PRB-Spezialtiefbau GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Hartmut Rüffert Projektentwicklung, Inh. Hartmut Rüffert: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Praxis Dr. Hauffe: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Bestattungshaus Hans-Jürgen Barz, Inhaber: Hans-Jürgen Barz: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Robert Rothe Feuerschutz GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Darpe Bürocenter GmbH & Co. KG: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Fremdsprachenservice International Rudolf Behrens: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Übersetzungsdienst Elvira Rosin: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for ASTRA®-DETEKTIVE e.K.: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Cohn Digital-Center GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Mang + co, Buch- und Verlagsdruckerei GmbH + Co. KG: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Copy Cabana, Inhaber: Gabriele Mayer: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for baru systems: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for EDV-Service Rauer GmbH & Co. KG: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for ENERGIEBUDE - Marc Mauser: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Batteriepower Livio Abbagnale: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Gräb Schrotthandel GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Aura Escort Köln: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Aura Escort Frankfurt: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Fahrschule und Ferienfahrschule A. Stern e. K., Inh. Günter Gaaß: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Fahrschule Schneider GbR: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for NeoDerm, Inhaber: Benjamin Bucher: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Jungeblut & Friends, Inhaber: Lisa-Marie Jungeblut: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Praxis für Podologie, Inh. Anke Schmitz: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for BUG Büro für Umweltschutz und Geotechnik Dipl.-Geol. Achim von Hein: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Gunter Thomas Kanalservice & Hausmeisterdienste: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for HMS Hausmeister-Service Roland Bertuleit e.K.: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Bibi Hausmeisterservice | Inhaber: Azem Bibic: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for GastroMaps.at: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Vanedler UG (haftungsbeschränkt): {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Clean Optimal GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Böhm Gebäudereinigung GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Main-Kinzig Kanal- und Rohrreinigungsservice, Inh. Klaus Dieter Wendler e.K: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Hofmeister Sicherheitstechnik GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Wimmelmeier Fenster und Türen GmbH & Co. KG: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Aero&Inkeaters: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Silke´s Dog Service: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Höchstädter Klauenpflege GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Rheintechnik Weiland & Kasper GmbH & Co. KG: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Forellenhof Lenz GbR, Inh. Claudia und Dietmar Wamser: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Labradorzucht vom Egelsee Inh. Markus Kockskämper: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Fohlenhof Gebhard: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Frenk Transportdienste Inh. Christof Frenk: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Onlinecenter & Mobilitätshilfen Hannover UG: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Stübner Umzugsservice, Inhaber: Michael Stübner: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Holstenhallen Neumünster GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Walker Pyrotechnik: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Feuersteins Karussellbetriebe: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Schneeweiß Wäscherei- und Reinigungsgesellschaft mbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Cafe Maarblick, Inh. Bernd Lenerz: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Erste Liebe: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Café Anna, Inh. Benno Brecht: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Damgartener Catering & Partyservice: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for geschmacksArt im Golfclub Isernhagen UG (Haftungsbeschränkt): {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Zur Alten Ziegelei: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Ristorante Paganini, Inhaber: Domenico Giorgi: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Restaurant Weserterrassen, Inh. Prof. Dr. Klaus Hübotter: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Amperpark GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for KINDERWELT REGENBOGEN GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Reit- und Kutschtouristik Rainer Ortlepp, Inhaber Rainer Ortlepp: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Reitanlage Hof Timm: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Ponyhof Mormann: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Ausbildungsstall Jochen Leicht, Inhaber: Jochen Leicht: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Kanuverleih Paddel-Paul, Tobias Schnuchel: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for huber-recht.com: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Kfz-Sachverständigenbüro Rolf Dieter Dannehl, Inhaber: Herr Rolf Dieter Dannehl: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Eis Die KFZ-Sachverständigen GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Architekturbüro Heide Rückheim: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Petra Jendrian Steuerberaterin: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Dipl.-Volksw. Peter Burkhardt Steuerberater: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Burggraf Steuerberater: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Residenz Klingberg, Inh. Andrea Wohlgemuth: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Senioren- und Therapiezentrum Eichenhof GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Altenheim St. Raphael der Barmherzigen Brüder: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Alternative Altenhilfe GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Kontaktlinsenstudio FASSUNGSLOS, Inhaber: Jürgen Schroedel: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Praxis für Ergotherapie lebenswert, Inhaberin: Kerstin Ellinger: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Praxis für Ergotherapie Kathrin Kenzler: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Dr. med. Brigitte Bock: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Naturheilpraxis Christa Kunz: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Naturheilpraxis Hartmut Schwarz: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Gemeinschaftspraxis Hedda und Wolfgang Rühle: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Hörzentrum Denkert GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for City Sozial GmbH Hauskrankenpflege: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Klang- und Energiehäusle Weinmann: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Orthopädie-Schuhtechnik Dönau: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Aulenkamp Orthopädie -Schuhtechnik, Inhaber: Adrian Walkhofer-Liß: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Jacob Böhme Orthopädie-Schuhmacher GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Orthopädieschuhmachermeister Denis Brandt: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Physiotherapie Anke Habermann: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Inka Domnick Supervision, Coaching, Teamentwicklung: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Dipl.-Psychologe Wolfgang Beckert: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Tierärztliche Praxis Solveigh von Jordans: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Aus Liebe zur Haut Wellness & SPA: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Zahnarztpraxis Dr. Gericke M. Sc. & Praxisteam: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Hugo Frosch GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Heimwerkerbedarf Ritter, Inh. Andy Ritter: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Dobermann GmbH & Co. KG: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for KLP Baumaschinen GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Econ Werkstattausrüstungs GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for LED2WORK GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for BNP Brinkmann GmbH & Co. KG: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Bootswerft Krieg GmbH & Co. KG: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Wümme Kanuvermietung: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Walter Furrer Musterkartenfabrikation: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Grinbold-Jodag GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Akzente im Kaisers vis a vis GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Agentur für Saisonprodukte Best Season GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for deko-sign gmbh: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Zweiradhütte, Inh. Marcus Krentzel: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Fahrradfachgeschäft Meyer, Inh. Andreas u. Mathias Meyer GbR: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Fliesen Wangler GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Platten-König Wipperfürth GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for CERAMICA-FLIESENDESIGN: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for A. Schapke Kühl u. Klimaanlagen GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for D. Bachteler, Inh. Dieter Bachteler: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for HMH Hülsmann, Inh: Heinz Hülsmann: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Schwarz Holz & Kunststoff GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Thermorollen und Kassenrollen von Bekaroll: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Bäckerei - Konditorei Dietmar Stümper: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Julias Küchenwelt: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Carl Lönne u. Sohn GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for TronicDesign GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for kabeltronik® Arthur Volland GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Werner Mann Orgelbau-Meisterbetrieb: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for augusta laborbedarf GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Die Goldschmiede Willeke: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Carl Tritschoks GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for agu | Goldmann Landschaftsarchitektur: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for KIMPEL Architekten GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Architekturbüro u. Energieberatung Dipl.-Ing. (FH) Dirk Kohler: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for A&B Architektur & Baukonzepte GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for ALUMONT GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Krüger - Arbeitsbühnen GmbH, Inh. Udo Krüger: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for WIESER Agrar- und Gartentechnik, Inh. Helmut Wieser e.K.: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for RG-Maschinenhandel: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for SPINDLER Dachdeckerei-Spenglerei GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Schlegel & Koplanski GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Günter Fippl Dachtechnik GmbH & Co. KG: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Lenzen Bedachungen GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Gert Heuken Dachdecker- und Maurermeister: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for SAB-Thüringen GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Petzold und Otto GbR: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Fliesenlegerei Vogler: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Schilling GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Jens Erbe Garten- und Landschaftsbau GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Holzbau Uphues, Inh. Stefan Uphues: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Küper Tischlerei/Trockenbau: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Holz Kranz Leo Kranz GmbH & Co. KG: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for CT Immobilienmakler Magdeburg®: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Allgäuer Wohnungsverwaltungsgesellschaft mbH & Co. Treuhandgesellschaft KG: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for EEA-Dr. Schäffler Germany GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Bauelemente Dahmen: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Thranberend Teppichböden GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Malerfachbetrieb Renè Wieruch: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Pink Farb & Design GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for ColorBase Lackierbedarf, Sven Hamann e.K.: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for HEITZ GmbH, Metallbälge - Kompensatoren: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for ProDEKon Blechtechnik GmbH & Co. KG: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Hummel Präzision GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Thormann GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Precise Metal Production GmbH & Co. KG: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Steinmetzwerkstatt P. Hempel: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Dachprofis Hämisch & Partner: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Sonderleuchtenbau Wolfgang Schwarze: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Regatherm GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Abflussdienst Hans Schillinger: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Horseshoeing Team Stephan, Inhaber: Mathias Stephan: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for CBG - Container Bau Gesellschaft mbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Sigmar Mothes Hochdrucktechnik GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Globus Drahtseil GmbH & Co. KG: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Strautmann Hydraulik GmbH & Co. KG: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Niemann Anlagenbau e.K.: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Kientsch Industriebau GmbH & Co. KG: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for ZS Zylinder Service GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Schlammer Maschinen: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Mürdter Werkzeug- und Formenbau GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Waffen Engel: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Ingenieurbüro Holger Quast: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Saint-Gobain Performance Plastics Isofluor GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Maschinenfabrik KEMPER GmbH & Co. KG: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for PROMStahl GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for LOTUS Personalservice GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Praxis für Lerntherapie, Familienberatung und affektives Lernen Wolfgang Reschke: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Institut für klassische Homöopathie Lindau, Inhaber: Elisabeth Majhenic: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Paritätische Schulen für soziale Berufe gGmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for CC CollegeCouncil gGmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Orgelbaumuseum Schloss Hanstein e.V.: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Gottfried-Keller-Zentrum: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Tanzstudio Redlight Dance, Inh. Wiebke Schröder: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Central & Union Filmtheater e.K., Inhaber: Claus Wollenschläger: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Omnibus-Reisen Rolf Farrenkopf: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Omnibusverkehr Klumpp GmbH & Co. KG: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Ferienwohnungen Haus Herzogenberg: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Heinrichs Ferienhäuser: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Ferienhof Henning Ommen: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Reisedienst Fischer: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Oscar Reisen GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Personenschifffahrt Theo Dohr: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Rivers 2 Oceans Kreuzfahrten e.K.: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for proLogistik GmbH + Co KG: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for TACOS Technische und Administrative Computer-Systeme GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Quick Druck: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Stöckler KFZ Technik, Inhaber: Thomas Stöckler: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Print & Service Wilhelm Pilsner e.U.: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Textilreinigung - Wäscherei Werner Lebl: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for SpeedClean Gebäudereinigung Christian Mailänder: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Almrausch Planai: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Spanische Hofreitschule: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Buchhaltung Agnes Beisteiner: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Dr. med. Birgit Brandner: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Aktiv & Vital Forum Isabella Wulz e. U.: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Mütterstudio Tulln: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Orthopädie Schuhtechnik Nindl GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for A.Novak GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Praxis für Krankengymnastik, Inh. Katja Bandlow und Bettina Ulfert GbR: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Psychotherapie Linz Leonding - Mag Martina Simbürger MAS: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for SlowDown: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Kieferorthopädie Willi Minich: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Dr. med. dent. Gregor Ley, BA, Facharzt für Zahn-, Mund- und Kieferheilkunde: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Kathrin´s Kinderwelt Inh. Hofer Kathrin e.U.: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Lechtaler Schuhhaus - Gerhard Hosp, Inhaber: Gerhard Hosp: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Creatives und Papier - Friederike Siebenhofer: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for AUSTROSAAT, Österreichische Samenzucht- u. Handels-Aktiengesellschaft: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Wash | Wolfgang Seiwald: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Fischer Schuhe: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Z&H Blitzschutzbau GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Gemeinnützige Bau- und Siedlungsgenossenschaft FRIEDEN: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Hubertus GOLLER GesmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Tom Veith Feuershow und Zaubershow: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Ferienhotel Angerhof, Inhaber: Hermann Josef Senn: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Hotel Seerose: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Buschenschank Luttenberger: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Weinbau Hermine Kovacs: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for MALAT Weingut GmbH & Co KG: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for ef16 Restaurant Weinbar: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Steirereck: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Lugeck: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Patara Restaurant Vienna GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Fankhauser AG Huttwil: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for TS-Velos GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Nocera & Strub AG: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Druckerei Lutz AG: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for ACR Energiebohr AG: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Schneider Atelier Renaissance: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Simon's Steakhouse Grill & Restaurant & Bar: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Pfotensalon Virginia Gafner: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Restaurant Bärgbeizli Bidmi: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for MAROWIL Fischereiartikel, Inh. Robert Flury: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Maya Hauri Vergnügungsbetriebe: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for H&E Kutschenfahrten, Marie-Theres Eggermann und Heimo Haas: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Kutschenfahrten und Fahrsport - Stall Schönenberger, Familie Monika und Armin Schönenberger: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Modelleisenbahnen H. R. Gehri, Inh. Stefan Bosshard: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for QueensRanchAcademy AG: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Tauchsport Signer GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for ZIB Tribastone GmbH, Zentrum für interdisziplinäre Begutachtungen: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Gesundheitspraxis Solara, Karin Büchler Kant. appr. Heilpraktikerin (AR): {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Gesundheitspraxis Saladin: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Massagepraxis Lucia Birri: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Prinzli Spielwaren, Inh.: Doris Kälin: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Peterhans Handwerkercenter AG: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Vilfil GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Teppich-Huus Breiti AG: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Piano Music Simmen, Inhaber: Herr Matthias Simmen: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for H. U. Bernhard Instrumentenbauer: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for jermann architekten und raumplaner ag: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Trenovag AG: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Fennerboden Roger Fenner: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Schreinerei Aeschlimann GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Heusser Montagen: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Müller Heizung-Service AG: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for HPV Rorschach: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Musikschule Zürcher Oberland: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Benediktinerkloster Mariastein: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Bildhaueratelier Meier GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Ferienwohnungen Chasa Sulai: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Piz Ot Samnaun - Bed and Breakfast: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Brisoft AG: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Designstudios GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Café Henrici: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Babu's: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Grande Café & Bar: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Café des Amis: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Milchbar - das Gaumenfreudenhaus: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Kafi Freud: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Ayfairy's Café: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Christoph Mlottek Transporte, Erdbewegungen: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for M & K Witten: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for nan: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Yaprak Tantuni: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Apartmenthaus Schneefalke: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Apartmenthaus Wolf: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Bergrestaurant Alpstubli: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Restaurant Gaessli: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Parkett & Fußbodentechnik Felkel: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for ÄSTHETIKBODEN Petersen: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Ingenieurbüro-GK: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Blumenladen '. Königsberger Strauß': {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Blumenladen: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for L: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Ristorante Pizzeria Weisses Kreuz: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Papillon Geschenke: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for César: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Raßmann Bau GmbH & Co. KG: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Ferienwohnung Freyung: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Ferienpark Geyersberg: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Akaj- Gebäudereinigung: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Bozena Kandziora: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Pizza City in Herne ️: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Hotel Luzern Engel: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Alte Schmiede: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Restaurant Dägerlohn: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for t: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Änderungsschneiderei Kasem, ehemals Naki: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Restaurant & Pizzeria Militärgarten: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for montagarchitekten GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Sirwan Kfz- & Hobbywerkstatt: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for DEDAIL: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for a&b Möbeltransport GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Johannes Grosch Raumgestaltung: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Chiva & Jools, Ralf Strobl: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Job Atelier: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for 360°Firmen Fit UG (hb): {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Ferienwohnung Theas Huske 'Uns Lütje Welt': {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for flixxfoto: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Wilma Glitter: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for 1a mobile Autoreinigung: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Hand- und Nagelstudio Hände nett Maike Rehbein: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Gebäudeservice-reidt Frank Reidt: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Lukas Gesinn Erd- und Abbruchunternehmen: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Advisory-Service-Facilitymanagement: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for 24-h Schlüsseldienst Dietrich e.K.: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Floorwell GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Maler & Trockenbau: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Mobile Tierheilpraxis Riga: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Bauteam VilmasSamstagSonntag: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for MesseWeber: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Andre Streck Übersetzer und Dolmetscher für Russisch: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Taha Dienstleistungen: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Sportbootschule Wagner: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Debeka | Versichern und Bausparen Über...: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Thekla Evers: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Loppersum Canhusen Sporré: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Heinrich Reinartz: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Hier entsteht eine neue Homepage: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Helmut Groß: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Grundschule Norddeich: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Reisen nach Plan: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for von Stern & Cie. GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Jade Energy GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Rail Marketing Gas- und Chemie Umschlag GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for vavorit GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for As-German GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Studio Hamburg Enterprises GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Lemounte IT GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for FZL 3D GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Aitech Engineering GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Brigid Innovation Gmbh: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Kunz Metallbau GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Gebrüder Grüske GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Ofenbau Unterseher GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for Fastr GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
# API Response for dck media GmbH: {'candidates': [], 'error_message': 'The provided API key is invalid.', 'status': 'REQUEST_DENIED'}
#                                    firma                  street    plz  \
# 0                Autohaus Hentschel GmbH   Vahrenwalder Str. 141  30165
# 1                  Autohaus Siegmar GmbH  Anton-Erhardt-Straße 5   9117
# 2         Autohaus Zückner GmbH & Co. KG           Gildestraße 5  91154
# 3                            Auto Böhler            Ottostraße 6  76227
# 4    EJP Frank Bach & Katarzyna Bach GbR     Elisabethstrasse 24   2826
# ..                                   ...                     ...    ...
# 379                  Kunz Metallbau GmbH     Adolf-Todt-Str. 28   65203
# 380                 Gebrüder Grüske GmbH            Meisenweg 17  82110
# 381              Ofenbau Unterseher GmbH     Kufsteiner Str. 49   83126
# 382                           Fastr GmbH     Kurfürstendamm 217   10719
# 383                       dck media GmbH    Von-Steuben-Str. 18   48143
#
#                    city                             telefon country  \
# 0              Hannover         +49_x001D_17_x0011_86221169      DE
# 1              Chemnitz  +_x001D__x0004_49179_x0008_9703167      DE
# 2                  Roth                     0049176-9142078      DE
# 3             Karlsruhe          /179/00182_x000C__x0007_38      DE
# 4               Görlitz          Hotline: 176-0699874 (+49)      DE
# ..                  ...                                 ...     ...
# 379           Wiesbaden                                 NaN      DE
# 380           Germering                                 NaN      DE
# 381   Flintsbach am Inn                                 NaN      DE
# 382              Berlin                                 NaN      DE
# 383  Münster, Westfalen                                 NaN      DE
#
#      country code   cleaned phone number      flag salutation first name  \
# 0              49        117001186221169  bad data    No data    No data
# 1              49  100044917900089703167  bad data    No data    No data
# 2              49             1769142078  bad data    No data    No data
# 3              49      17900182000000738  bad data    No data    No data
# 4              49             1760699874  bad data    No data    No data
# ..            ...                    ...       ...        ...        ...
# 379            49                    NaN  bad data       Herr    Richard
# 380            49                    NaN  bad data       Herr     Werner
# 381            49                    NaN  bad data       Herr      Georg
# 382            49                    NaN  bad data       Herr      Achim
# 383            49                    NaN  bad data       Herr    Dominik
#
#         surname  digit length  firma length unique_id new_address  \
# 0       No data          15.0          23.0     bad_1        None
# 1       No data          21.0          21.0     bad_2        None
# 2       No data          10.0          30.0     bad_3        None
# 3       No data          17.0          11.0     bad_4        None
# 4       No data          10.0          35.0     bad_5        None
# ..          ...           ...           ...       ...         ...
# 379        Kunz           NaN          19.0   bad_380        None
# 380      Grüske           NaN          20.0   bad_381        None
# 381  Unterseher           NaN          23.0   bad_382        None
# 382      Gasper           NaN          10.0   bad_383        None
# 383       Muhle           NaN          14.0   bad_384        None
#
#     new_phone_number    enrichment
# 0               None  not enriched
# 1               None  not enriched
# 2               None  not enriched
# 3               None  not enriched
# 4               None  not enriched
# ..               ...           ...
# 379             None  not enriched
# 380             None  not enriched
# 381             None  not enriched
# 382             None  not enriched
# 383             None  not enriched
#
# [384 rows x 18 columns]

# %%
enriched_bad_data['enrichment'].value_counts()
# Out:
# enrichment
# not enriched    384
# Name: count, dtype: int64

# %%
enriched_bad_data.head()
# Out:
#                                  firma                  street    plz  \
# 0              Autohaus Hentschel GmbH   Vahrenwalder Str. 141  30165
# 1                Autohaus Siegmar GmbH  Anton-Erhardt-Straße 5   9117
# 2       Autohaus Zückner GmbH & Co. KG           Gildestraße 5  91154
# 3                          Auto Böhler            Ottostraße 6  76227
# 4  EJP Frank Bach & Katarzyna Bach GbR     Elisabethstrasse 24   2826
#
#         city                             telefon country  country code  \
# 0   Hannover         +49_x001D_17_x0011_86221169      DE            49
# 1   Chemnitz  +_x001D__x0004_49179_x0008_9703167      DE            49
# 2       Roth                     0049176-9142078      DE            49
# 3  Karlsruhe          /179/00182_x000C__x0007_38      DE            49
# 4    Görlitz          Hotline: 176-0699874 (+49)      DE            49
#
#     cleaned phone number      flag salutation first name  surname  \
# 0        117001186221169  bad data    No data    No data  No data
# 1  100044917900089703167  bad data    No data    No data  No data
# 2             1769142078  bad data    No data    No data  No data
# 3      17900182000000738  bad data    No data    No data  No data
# 4             1760699874  bad data    No data    No data  No data
#
#    digit length  firma length unique_id new_address new_phone_number  \
# 0          15.0          23.0     bad_1        None             None
# 1          21.0          21.0     bad_2        None             None
# 2          10.0          30.0     bad_3        None             None
# 3          17.0          11.0     bad_4        None             None
# 4          10.0          35.0     bad_5        None             None
#
#      enrichment
# 0  not enriched
# 1  not enriched
# 2  not enriched
# 3  not enriched
# 4  not enriched

# %% [markdown]
# ## Writing the data to excel file

# %%
# uncomment the codes if you need to write into excel file again
# enriched_bad_data.to_excel('../Inputs/leads_enriched_data.xlsx', index=False)
